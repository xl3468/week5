# %% [markdown]
# <a href="https://colab.research.google.com/github/tleitchColumbia/week5/blob/main/Numpy_LinearAlgebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
mat = np.arange(100,116).reshape(4,4)

# %%
print(mat)
# Out:
# [[100 101 102 103]
#  [104 105 106 107]
#  [108 109 110 111]
#  [112 113 114 115]]

# %%
np.linalg.inv(mat)
# Out:
# array([[ 4.69124961e+13, -7.03687442e+13,  0.00000000e+00,
#          2.34562481e+13],
#        [-7.03687442e+13,  1.40737488e+14, -7.03687442e+13,
#          0.00000000e+00],
#        [-0.00000000e+00, -7.03687442e+13,  1.40737488e+14,
#         -7.03687442e+13],
#        [ 2.34562481e+13, -0.00000000e+00, -7.03687442e+13,
#          4.69124961e+13]])

# %%
np.linalg.eig(mat)
# Out:
# EigResult(eigenvalues=array([ 4.30185966e+02, -1.85966085e-01, -4.47083143e-15,  1.19197020e-14]), eigenvectors=array([[-0.47169744,  0.67598178,  0.21536006,  0.19939064],
#        [-0.49027799,  0.22879235,  0.08821977, -0.64609049],
#        [-0.50885854, -0.21839709, -0.82251973,  0.69400908],
#        [-0.52743909, -0.66558652,  0.51893989, -0.24730922]]))

# %%
X = np.array([[1,2],[3,4]])
y = np.array([5,6])
z=np.linalg.solve(X,y)
z*y
# Out:
# array([-20.,  27.])

# %%
X@z
# Out:
# array([5., 6.])

# %%
mat @ mat
# Out:
# array([[43056, 43462, 43868, 44274],
#        [44752, 45174, 45596, 46018],
#        [46448, 46886, 47324, 47762],
#        [48144, 48598, 49052, 49506]])

# %%
mat[0]
# Out:
# array([100, 101, 102, 103])

# %%
mat[0] @ mat
# Out:
# array([43056, 43462, 43868, 44274])

# %%
mat @ mat[0]
# Out:
# array([41214, 42838, 44462, 46086])

# %%
mat @ mat[0].T
# Out:
# array([41214, 42838, 44462, 46086])

# %%
mat.T
# Out:
# array([[100, 104, 108, 112],
#        [101, 105, 109, 113],
#        [102, 106, 110, 114],
#        [103, 107, 111, 115]])

# %%
mat
# Out:
# array([[100, 101, 102, 103],
#        [104, 105, 106, 107],
#        [108, 109, 110, 111],
#        [112, 113, 114, 115]])
