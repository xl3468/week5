# %% [markdown]
# <a href="https://colab.research.google.com/github/tleitchColumbia/week5/blob/main/Numpy_Indexing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
nums = np.arange(1,11)*100

# %%
nums
# Out:
# array([ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1000])

# %%
nums[:5]
# Out:
# array([100, 200, 300, 400, 500])

# %%
nums[5:]
# Out:
# array([ 600,  700,  800,  900, 1000])

# %%
nums[0]
# Out:
# 100

# %%
nums[1]
# Out:
# 200

# %%
nums[-1]
# Out:
# 1000

# %%
nums[-2]
# Out:
# 900

# %%
nums[-3:]
# Out:
# array([ 800,  900, 1000])

# %%
nums[2:5]
# Out:
# array([300, 400, 500])
